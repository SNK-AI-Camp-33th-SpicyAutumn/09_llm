# %% [markdown]
# # Checkpoint로 이어지는 LangGraph 대화 기억
#
# LangGraph의 **Persistence**는 한 번의 그래프 실행이 끝난 뒤에도 State를 보존하는 기능이다. 이전 대화를 State에 저장하면 다음 질문에서 같은 대화를 이어 갈 수 있다.
#
# ## 먼저 구분할 용어
#
# 대화 기억은 모델이 내용을 내부에 외우는 기능이 아니다. LangGraph runtime이 현재 작업 데이터인 State를 저장하고, 다음 호출 전에 다시 불러오는 구조이다.
#
# - **State**: Node들이 현재 실행에서 함께 읽고 갱신하는 작업 데이터이다. 이 실습에서는 `messages`가 대화 이력이다.
# - **Checkpointer**: State를 저장하고 불러오는 저장 관리자이다.
# - **Checkpoint**: 특정 실행 단계에서 저장한 State snapshot 하나이다.
# - **thread**: 같은 대화에 속한 Checkpoint history이다.
# - **thread_id**: 저장하거나 불러올 thread를 지정하는 key이다. 사용자 인증을 담당하지 않는다.
# - **StateSnapshot**: 저장된 Checkpoint를 `get_state()`로 읽었을 때 반환되는 조회 객체이다.
#
# 핵심 흐름은 `thread_id로 thread 선택 → Checkpointer가 최신 Checkpoint 복구 → State에 새 입력 병합 → 그래프 실행 → 새 Checkpoint 저장` 순서이다.
#
# `InMemorySaver`는 Checkpointer의 한 구현이며 Checkpoint를 현재 Python 프로세스의 RAM에 저장한다. 프로세스가 끝나면 사라지므로 수업과 개발에 적합하고, 운영 환경에서는 DB 기반 Checkpointer를 사용한다.
#
# Checkpoint는 한 thread 안에서 이어지는 **단기 기억**을 담당한다. 여러 thread에서 공유할 사용자 선호나 장기 정보는 Store가 담당한다.
#
# ### 대화 이어가기와 중단된 실행 재개의 차이
#
# 이 실습의 이어가기는 같은 `thread_id`로 새 `graph.invoke()`를 호출해 과거 State 위에서 **새 Turn을 시작하는 방식**이다. 중단된 Node를 `Command(resume=...)`로 재개하는 Human-in-the-loop의 resume와는 다르며, 후자는 다음 노트북에서 다룬다.
#
# ## 이번 실습에서 확인할 것
#
# 같은 `thread_id`를 재사용하면 이전 `messages`가 복구되고, 다른 `thread_id`를 사용하면 대화가 분리되는지 비교한다. 마지막에는 `graph.get_state()`로 저장된 최신 State를 직접 읽는다.

# %% [markdown]
# ## 실행 환경 준비
#
# Persistence가 있는 Tool loop를 실행할 패키지를 현재 Jupyter 커널 환경에 설치한다.
#
# - `langgraph`: 그래프와 `InMemorySaver`를 제공한다.
# - `langchain-openai`: OpenAI Chat Model을 연결한다.
# - `langchain-tavily`: 검색 Tool을 제공한다.
# - `python-dotenv`: `.env`의 설정을 환경 변수로 불러온다.
#
# DB에 저장하는 운영용 Checkpointer는 별도 패키지가 필요하지만, 이 실습은 RAM에 저장하는 `InMemorySaver`만 사용한다.

# %%
# %pip install -U langgraph langchain-openai langchain-tavily python-dotenv
# Out:
# Requirement already satisfied: langgraph in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.2.11)
# Requirement already satisfied: langchain-openai in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.5.1)
# Requirement already satisfied: langchain-tavily in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (0.2.18)
# Requirement already satisfied: python-dotenv in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (1.2.3)
# Requirement already satisfied: langchain-core<2,>=1.4.7 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (1.5.4)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (0.4.2)
# Requirement already satisfied: pydantic>=2.7.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (2.13.4)
# Requirement already satisfied: xxhash>=3.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph) (3.8.1)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.10.16)
# Requirement already satisfied: packaging>=23.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (24.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (4.16.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-core<2,>=1.4.7->langgraph) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2,>=1.4.7->langgraph) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (4.14.2)
# Requirement already satisfied: distro>=1.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.34.2)
# Requirement already satisfied: sniffio>=1.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (1.3.1)
# Requirement already satisfied: zstandard>=0.23.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (0.25.0)
# Requirement already satisfied: certifi in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (3.18)
# Requirement already satisfied: h11>=0.16 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: openai<4.0.0,>=2.45.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai) (3.2.0)
# Requirement already satisfied: tiktoken<1.0.0,>=0.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-openai) (0.13.0)
# Requirement already satisfied: httpx2<3,>=2.7.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (2.10.0)
# Requirement already satisfied: jiter<1,>=0.10.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (0.16.0)
# Requirement already satisfied: tqdm>4 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from openai<4.0.0,>=2.45.0->langchain-openai) (4.70.0)
# Requirement already satisfied: httpcore2==2.10.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (2.10.0)
# Requirement already satisfied: truststore>=0.10 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from httpx2<3,>=2.7.0->openai<4.0.0,>=2.45.0->langchain-openai) (0.10.4)
# Requirement already satisfied: regex in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from tiktoken<1.0.0,>=0.7.0->langchain-openai) (2026.7.19)
# Requirement already satisfied: aiohttp<4.0.0,>=3.11.14 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-tavily) (3.14.3)
# Requirement already satisfied: langchain<2.0.0,>=1.0.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from langchain-tavily) (1.3.15)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (2.7.1)
# Requirement already satisfied: aiosignal>=1.4.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from aiohttp<4.0.0,>=3.11.14->langchain-tavily) (1.24.5)
# Requirement already satisfied: charset_normalizer<4,>=2 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (3.4.9)
# Requirement already satisfied: urllib3<3,>=1.26 in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2,>=1.4.7->langgraph) (2.7.0)
# Requirement already satisfied: colorama in C:\Users\playdata2\miniforge3\envs\llm_env\Lib\site-packages (from tqdm>4->openai<4.0.0,>=2.45.0->langchain-openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## 모델·검색 인증과 선택 추적 설정
#
# `.env`는 API key와 모델 ID를 코드 밖에서 관리하는 설정 파일이다. 아래 셀은 비밀값을 출력하지 않고 누락된 환경 변수의 이름만 검사한다.
#
# - `OPENAI_API_KEY`: Chat Model 호출에 필요한 필수값이다.
# - `TAVILY_API_KEY`: 검색 Tool 호출에 필요한 필수값이다.
# - `OPENAI_CHAT_MODEL`: 호출할 모델 ID이며 없으면 수업용 기본값을 사용한다.
# - `LANGSMITH_API_KEY`: 실행 추적에 사용하는 선택값이다. 없어도 그래프와 Checkpoint 실습은 실행된다.
#
# `setdefault()`는 환경 변수가 없을 때만 기본값을 넣는다. 따라서 이미 정해진 LangSmith 설정을 덮어쓰지 않는다.

# %%
import os
from dotenv import find_dotenv, load_dotenv

dotenv_path = find_dotenv(usecwd=True)
load_dotenv(
    dotenv_path,
    override=False,
)

if os.getenv("LANGSMITH_API_KEY"):
    os.environ.setdefault("LANGSMITH_TRACING", "true")
    os.environ.setdefault("LANGSMITH_PROJECT", "langgraph-memory")

OPENAI_CHAT_MODEL = os.getenv("OPENAI_CHAT_MODEL", "gpt-5.6-luna")

# %% [markdown]
# ## 그래프 밖에서 검색 Tool 점검하기
#
# `TavilySearch`는 검색어를 받아 웹 검색 결과를 반환하는 Tool이다. Checkpoint 실습에 들어가기 전에 Tool만 직접 호출해 인증·네트워크·반환 구조를 먼저 확인한다.
#
# `max_results=2`는 한 번의 검색에서 가져올 최대 결과 수이다. 결과 수를 줄이면 이후 ToolMessage에 저장되는 검색 문맥이 불필요하게 커지는 것을 막을 수 있다.

# %%
from langchain_tavily import TavilySearch

tavily_tool = TavilySearch(max_results=2)

tavily_tool.invoke({
    "query": "지금 서울 날씨는?"
})
# Out:
# {'query': '지금 서울 날씨는?',
#  'follow_up_questions': None,
#  'answer': None,
#  'images': [],
#  'results': [{'url': 'https://www.aqi.in/weather/ko/south-korea/seoul/seoul',
#    'title': 'Seoul 날씨 상태: 기온 | 30일 예보',
#    'content': '3.6 kmph /  SW\n\n마지막 업데이트:  17 Aug 2026, 07:57 PM\n\n## FAQs About Seoul Weather Conditions\n\n1. Seoul의 오늘 18 8월 2026 현재 기온은 얼마인가요?\n\nSeoul의 현재 기온은 22°C이며, 체감 온도는 27°C입니다. 오늘 예보에 따르면 최고 기온은 31°C, 최저 기온은 22°C로 04:30 AM 18 8월 2026 기준 하루 동안 9도의 기온차가 있습니다.\n\n2. Seoul의 오늘 현재 날씨 매개변수는 무엇인가요?\n\n04:30 AM 18 8월 2026 기준 Seoul의 현재 날씨 상태에 대한 전체 개요는 다음과 같습니다:\n상태 : Fog\n기온 : 22°C 쾌적한 (체감 27°C)\n습도 : 98%\n풍속 : 3.6 km/h (SSE 방향, 163도), 돌풍 1 m/s\nUV 지수 : 0 (Low\n기압 : 1008 mb\n운량 : 100%\n시정 : 0 km\n강수량 : 0 mm (강우 확률 38%) [...] 04:30 AM 18 8월 2026부터 Seoul의 10일 예보는 다음 추세를 보입니다:\n오늘 (8월 18) : 기온 26°C, 습도 75% 및 Sunny 상태.\n수요일 (8월 19) : 기온 26°C, 습도 73% 및 Overcast 상태.\n목요일 (8월 20) : 기온 26°C, 습도 72% 및 Overcast 상태.\n금요일 (8월 21) : 기온 23°C, 습도 88% 및 Rain Shower 상태.\n토요일 (8월 22) : 기온 25°C, 습도 84% 및 Overcast 상태.\n일요일 (8월 23) : 기온 26°C, 습도 82% 및 Rain Shower 상태.\n월요일 (8월 24) : 기온 23°C, 습도 94% 및 Rain Showers 상태.\n화요일 (8월 25) : 기온 23°C, 습도 98% 및 Rain Showers 상태.\n수요일 (8월 26) : 기온 24°C, 습도 74% 및 Rain Showers 상태. [...] Seoul Weather Conditions\n\nCurrent Temperature Level\n\nfog\n\n온도 27°C\n\nChances of Rain42%\n\n37AQI\n\n깨끗한 공기.\n\n습도\n\n98%\n\n높은 습도는 불쾌감을 유발할 수 있습니다.\n\nfog\nfog\nfog\nmist\npatchy rain possible\npatchy rain possible\npatchy rain possible\nsunny\nsunny\nsunny\nsunny\nsunny\nsunny\nsunny\nsunny\nsunny\nclear\nclear\nclear\nclear\npartly cloudy\novercast\nhaze\nhaze',
#    'score': 0.81875163,
#    'raw_content': None,
#    'id': 'b54683-00'},
#   {'url': 'https://korean.visitseoul.net/weather',
#    'title': '서울 실시간 날씨 정보 | 서울 공식 관광정보 웹사이트',
#    'content': '| 항목 | 오늘 : 2026-08-08 | 내일 : 2026-08-09 | 모레 : 2026-08-10 |\n| 날씨 | 구름많고 한때 소나기  구름많고 한때 소나기 | 맑음  맑음 | 구름많음  구름많음 |\n| 최저/최고기온 (℃) | 25℃ / 35℃ | 25℃ / 33℃ | 25℃ / 33℃ |\n| 강수확률 | 0% / 60% | 0% / 10% \n\n#### 대기오염 상세\n\n대기오염 상세 표 : 항목(오늘예보, 내일예보, 모레예보), 미세먼지(PM10), 초미세먼지(PM2.5)\n\n| 항목 | 오늘예보 | 내일예보 | 모레예보 |\n| 미세먼지 (PM10) | 미세먼지좋음 좋음 | 미세먼지좋음 좋음 | 미세먼지좋음 좋음 |\n| 초미세먼지 (PM2.5) | 초미세먼지좋음 좋음 | 초미세먼지좋음 좋음 | 초미세먼지좋음 좋음 |\n\n#### 주간예보\n\n주간예보 표 : 항목별 날짜, 날씨, 최저/최고기온(℃) [...] | 항목 | 2026-08-08 | 2026-08-09 | 2026-08-10 | 2026-08-11 | 2026-08-12 |\n| 날씨 | 구름많고 한때 소나기 구름많고 한때 소나기 | 맑음 맑음 | 구름많음 구름많음 | 맑음 맑음 | 맑음 맑음 |\n| 최저/최고기온 (℃) | 25℃ / 35℃ | 25℃ / 33℃ | 25℃ / 33℃ | 25℃ / 35℃ | 25℃ / 34℃ |\n\n제공 : 케이웨더(Kweather)',
#    'score': 0.70336664,
#    'raw_content': None,
#    'id': 'de465d-01'}],
#  'response_time': 0.0,
#  'request_id': 'acdf3539-be28-465f-8e99-a93e5e82f219'}

# %% [markdown]
# ## Chat Model에 검색 Tool 사용법 연결하기
#
# `bind_tools()`는 Chat Model에 Tool의 이름·설명·입력 schema를 알려 준다. 모델은 검색이 필요하다고 판단하면 `tool_calls`를 포함한 `AIMessage`를 반환한다.
#
# 이 단계는 Tool을 **실행**하지 않는다. 실제 Tool 호출은 뒤에서 등록할 `ToolNode`가 담당한다.

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model_name=OPENAI_CHAT_MODEL,
    use_responses_api=True,
)

tools = [tavily_tool]

llm_with_tools = llm.bind_tools(tools)

# %% [markdown]
# ## Checkpoint 대화 기억을 완성할 네 구성 요소
#
# 여기까지 만든 `llm_with_tools`는 Tool 요청을 만들 수 있지만, 대화 이력을 저장하거나 다음 호출에서 복구하지는 않는다. 기억이 있는 Tool loop를 만들려면 다음 네 구성 요소를 연결해야 한다.
#
# 1. `State`: 저장할 `messages`와 새 message를 합치는 규칙이다.
# 2. `chatbot`: 복구된 `messages`를 읽어 다음 `AIMessage`를 만드는 Node이다.
# 3. `Checkpointer`: 실행 단계별 State를 `thread_id`에 따라 저장하고 불러오는 객체이다.
# 4. `CompiledStateGraph`: Node·Edge를 실행하고 Checkpointer에 저장 시점을 알려 주는 runtime이다.
#
# ```text
# 새 HumanMessage + thread_id
#             ↓
# Checkpointer가 최신 Checkpoint의 messages 복구
#             ↓
# add_messages로 새 입력 병합 → chatbot ↔ tools
#             ↓
# 실행 단계별 새 Checkpoint 저장 → 최종 State 반환
# ```
#
# ### 1. Checkpoint에 저장할 messages State 규칙 정의하기
#
# Checkpointer가 저장하는 대상은 모델 자체가 아니라 **그래프 State**이다. <br>
# State는 `messages` key 하나만 가지며 사용자·모델·Tool message가 실행 순서대로 들어간다.
#
# - 입력: Checkpoint에서 복구한 기존 `messages`와 Node가 반환한 새 message이다.
# - 변환: `add_messages` reducer가 새 message를 기존 목록 뒤에 병합한다.
# - 출력: 다음 Node와 다음 Turn이 읽을 수 있는 갱신된 `messages`이다.
# - 다음 사용처: Checkpointer가 갱신된 State를 새 Checkpoint로 저장한다.
#
# 같은 `thread_id`의 Checkpoint를 복구한 뒤 새 입력을 넣어도 과거 대화가 사라지지 않는 이유가 이 병합 규칙이다.

# %%
from typing import Annotated, TypedDict

from langchain_core.messages import AnyMessage
from langgraph.graph.message import add_messages

class State(TypedDict):
    messages: Annotated[list[AnyMessage], add_messages]

# %% [markdown]
# ### 2. 복구된 대화를 읽는 chatbot Node 정의하기
#
# `chatbot()`은 현재 thread의 `messages`를 모델에 전달하고 새 `AIMessage`를 State update로 반환한다. 뒤에서 `add_node()`로 등록하면 그래프의 Node가 된다.
#
# - 입력: Checkpoint에서 복구된 과거 message와 현재 Turn의 새 `HumanMessage`가 합쳐진 State이다.
# - 변환: `llm_with_tools`가 전체 대화를 읽고 일반 답변 또는 Tool 요청을 만든다.
# - 출력: `add_messages`에 전달할 새 `AIMessage` 하나이다.
# - 다음 사용처: Tool 요청 유무에 따라 Tool Node 또는 종료 경로로 이동하고, 갱신된 State는 Checkpoint에 저장된다.
#
# Node는 Checkpointer를 직접 호출하지 않는다. Node가 State update를 반환하면 LangGraph runtime이 실행 단계의 경계에서 저장을 요청한다. 이 셀은 함수 정의 단계이므로 모델 API는 아직 호출하지 않는다.

# %%
# 전달 받은 State에는 복구된 이전 대화 내역이 담겨있다!
def chatbot(state:State) -> dict:
    response = llm_with_tools.invoke(state["messages"])

    return {"messages": [response]}

# %% [markdown]
# ### 3. State를 저장할 Checkpointer 만들기
#
#
# ![LangGraph 공식 Checkpoint 구조](https://cdn.jsdelivr.net/gh/goat-skn-ai/image-repo@7f008bd902003af9b0138e956af0be37ffa7a9ff/08_llm/08_langgraph/01_langgraph_basics/04_official_checkpoints.png)
#
# 1. **Graph**: State가 Node와 Edge를 따라 이동한다.
# 2. **Super-step**: 현재 실행할 Node 묶음 하나가 한 단계가 된다. 순차 Node는 각각 별도 단계이다.
# 3. **Checkpoint**: 각 단계 경계에서 State·`next`·ID 등의 snapshot을 저장한다.
# 4. **Thread**: 같은 `thread_id`에 속한 Checkpoint들을 하나의 history로 관리한다.
# 5. **StateSnapshot**: 저장된 Checkpoint를 Python에서 조회할 때 사용하는 객체이다.
#
# 출처: [LangGraph Checkpointers 문서](https://docs.langchain.com/oss/python/langgraph/checkpointers)
#
# ---
#
# `InMemorySaver`는 위 Checkpoint들을 RAM에 저장하는 Checkpointer이다.
#
# - 입력: 컴파일된 그래프가 전달하는 `thread_id`와 실행 단계별 State snapshot이다.
# - 변환: 같은 `thread_id`의 Checkpoint들을 하나의 thread history로 구분해 보관한다.
# - 출력: 다음 호출에서 복구할 최신 Checkpoint와 조회 가능한 StateSnapshot이다.
# - 다음 사용처: `compile(checkpointer=checkpointer)`가 이 객체를 그래프 runtime에 연결한다.
#
# `InMemorySaver()` 객체를 만드는 것만으로는 아무 State도 저장되지 않는다. Python 프로세스가 끝나면 기록도 모두 사라지므로, 재시작 복구가 필요한 운영 서비스에는 PostgresSaver 같은 DB 기반 구현을 사용한다.

# %%
from langgraph.checkpoint.memory import InMemorySaver

# 현재 jupyter server 메모리를 저장소로 사용
checkpointer = InMemorySaver()

# %% [markdown]
# ### 4. 네 구성 요소를 Persistence가 있는 Tool loop로 조립하기
#
# 이제 앞에서 정의한 부품을 `StateGraph`에 등록하고 Checkpointer와 함께 컴파일한다.
#
# `prebuilt`는 반복해서 사용하는 표준 로직을 LangGraph가 미리 구현해 둔 구성 요소이다.<br>
# `ToolNode`와 `tools_condition`를 직접 구현하지 않고 `langgraph.prebuilt`에서 제공되는 것을 사용한다.
#
# - `State` → `StateGraph(State)`의 공유 데이터 schema이다.
# - `chatbot` → 모델의 다음 행동을 만드는 `"chatbot"` Node이다.
# - `ToolNode(tools)` → 모델의 `tool_calls`를 실제 실행하는 `"tools"` Node이다.
# - `tools_condition` → Tool 실행과 종료 중 다음 경로를 고르는 route function이다.
# - `checkpointer` → `compile(checkpointer=...)`에서 thread별 Persistence를 담당한다.
#
# `ToolNode`와 `tools_condition`은 Tool 실행 흐름을 담당하고, 대화 기억은 `checkpointer`가 담당한다.
#
# ```text
# START → chatbot → tools_condition
#                     ├─ tools → chatbot
#                     └─ END
#
# 각 실행 단계의 State ── checkpointer ──> thread_id별 Checkpoint
# ```
#
# `compile()`의 출력은 실행 가능한 `CompiledStateGraph`이다. 이 셀에서는 구조만 조립하므로 모델·Tool 호출과 Checkpoint 저장은 일어나지 않는다. `checkpointer` 인자를 생략하면 `thread_id`를 전달해도 이전 State가 자동으로 복구되지 않는다.

# %%
from langgraph.graph import END, START, StateGraph

from langgraph.prebuilt import ToolNode, tools_condition

workflow = StateGraph(State)    # Builder

# 노드 등록
workflow.add_node("chatbot", chatbot)
workflow.add_node("tools", ToolNode(tools)) # PreBuilt ToolNode

# 엣지 연결
workflow.add_edge(START, "chatbot")
workflow.add_edge("tools", "chatbot")

# 조건 분기 설정
workflow.add_conditional_edges(
    "chatbot",  # 분기할 Node
    tools_condition,
    # "chatbot" Node에서 반환되는 마지막 AIMessage에
    # tool_calls가 있다면 "tools", 없으면 END 반환
)

graph = workflow.compile(
    # 단게별 State를 thread_id 기준 CheckPoint로 저장한다.
    checkpointer=checkpointer
)  # 실행 가능한 형태로 변경

display(graph)

# %% [markdown]
# ## thread_id로 실제 저장·복구 흐름 확인하기
#
# 앞의 셀들은 기억에 필요한 규칙과 객체를 정의했다. 이제 `graph.invoke()`를 호출하면 처음으로 모델·Tool loop가 실행되고 Checkpointer가 State를 저장한다.
#
# 각 호출은 다음 순서로 처리된다.
#
# 1. 입력 State update와 `configurable.thread_id`를 받는다.
# 2. 같은 thread의 최신 Checkpoint가 있으면 State를 복구한다.
# 3. `add_messages`가 새 `HumanMessage`를 기존 이력 뒤에 합친다.
# 4. 그래프를 실행하고 단계별 State를 새 Checkpoint로 저장한다.
# 5. 누적된 `messages`를 포함한 최종 State를 반환한다.
#
# ### 1. user1 thread에 첫 번째 Turn 저장하기
#
# **Turn**은 사용자 입력과 그에 대한 모델 응답이 오가는 대화 한 차례이다. 첫 호출의 `thread_id`를 `user1`로 지정하고 이름이 포함된 `HumanMessage`를 전달한다.
#
# 아직 user1의 과거 Checkpoint가 없으므로 새 State에서 시작한다. `graph.invoke()`가 끝나면 실행 단계별 Checkpoint가 user1의 history에 추가되고, 최신 Checkpoint에는 사용자 입력과 모델 응답이 포함된다. 첫 Turn만으로는 기억을 증명할 수 없으므로 다음 셀에서 같은 `thread_id`를 재사용한다.

# %%
from langchain_core.messages import HumanMessage

# CheckPointer가 user1의 저장 위치를 선택하기 위한 설정이다.
user_config = {
    "configurable": {
        "thread_id": "user1"
    }
}

# llm에게 전달할 첫 메시지(첫 Turn)
user_input = {
    "messages": [HumanMessage(content="반가워. 내 이름은 홍길동이야.")]
}

user1_state = graph.invoke(
    user_input,   # 초기 state
    config = user_config,
    # 'user1' CheckPoint를 저장하고 불러올 thread 지정
)

user1_state["messages"][-1].content
# Out:
# [{'type': 'text',
#   'text': '반가워요, 홍길동님! 무엇을 도와드릴까요?',
#   'annotations': [],
#   'id': 'msg_0c5cd33b01e067f0006a83ee85465087d0b827ccf751b2eab8',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 2. 같은 user1 thread에서 이전 이름 회상하기
#
# 후속 호출에는 새 질문만 전달한다. 그러나 같은 `user1_config`를 사용하므로 Checkpointer가 user1의 최신 Checkpoint를 불러오고, `add_messages`가 새 질문을 과거 대화 뒤에 병합한다.
#
# - 입력: 이름이 없는 새 질문과 `thread_id="user1"`이다.
# - 변환: user1의 과거 `messages` 복구 → 새 질문 병합 → chatbot 실행 순서이다.
# - 출력: 과거 이름을 근거로 만든 최신 `AIMessage`이다.
# - 다음 사용처: 이번 Turn까지 포함한 State가 user1의 새 Checkpoint로 저장된다.
#
# 답변에 첫 Turn의 이름이 반영되면 모델이 숨겨서 기억한 것이 아니라 **복구된 messages를 다시 읽은 것**이다.

# %%
user_input2 = {
    "messages": [
        HumanMessage(content="내 이름이 뭐라고?")
    ]
}

user1_state = graph.invoke(
    user_input2,
    config = user_config,
)

user1_state["messages"][-1].content
# Out:
# [{'type': 'text',
#   'text': '홍길동님이에요.',
#   'annotations': [],
#   'id': 'msg_0c5cd33b01e067f0006a83efcee8f487d08f06f6b47fcab95e',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 3. 다른 user2 thread가 분리되는지 확인하기
#
# `thread_id="user2"`는 user1과 다른 Checkpoint history를 가리킨다. 같은 graph와 Checkpointer를 사용해도 `thread_id`가 다르면 user1의 messages를 불러오지 않는다.
#
# - 입력: 이름을 묻는 질문과 새 `thread_id="user2"`이다.
# - 변환: user2의 저장 기록만 조회하며, 기록이 없으므로 새 State에서 그래프를 실행한다.
# - 출력: user1의 이름을 근거로 사용하지 않은 최신 `AIMessage`이다.
# - 다음 사용처: user2의 첫 State가 user1과 별도의 Checkpoint로 저장된다.
#
# user2의 답변이 user1의 이름을 근거로 사용하지 않아야 thread 격리가 유지된 것이다. 단, `thread_id`는 저장 key일 뿐 인증 수단은 아니므로 서비스에서는 접근 권한을 별도로 검사해야 한다.

# %%
user222_config = {    # 새로운 thread_id 설정
    "configurable": {
        "thread_id": "user222"
    }
}

user222_input = {
    "messages": [
        HumanMessage(content="내 이름이 뭐라고?")
    ]
}

user222_state = graph.invoke(
    user222_input,
    config = user222_config,
)

user222_state["messages"][-1].content
# Out:
# [{'type': 'text',
#   'text': '아직 이름을 알려주지 않으셨어요.',
#   'annotations': [],
#   'id': 'msg_08a8e121fcf3ac5a006a83f10a91808199bf87ed0ef7e508f5',
#   'phase': 'final_answer'}]

# %% [markdown]
# ### 4. user1 thread로 돌아와 세 번째 Turn 이어 가기
#
# user2 호출 뒤 다시 `user1_config`를 전달한다. Checkpointer는 호출 순서가 아니라 `thread_id`를 기준으로 저장 위치를 선택하므로 user1의 최신 Checkpoint를 다시 복구한다.
#
# - 입력: 새 주제와 이름 회상을 함께 요구하는 질문, `thread_id="user1"`이다.
# - 변환: user1의 두 Turn 복구 → 새 질문 병합 → 그래프 실행 순서이다.
# - 출력: 새 주제와 저장된 이름을 함께 반영한 최신 `AIMessage`이다.
# - 다음 사용처: 세 번째 Turn까지 포함한 State가 user1 history의 최신 Checkpoint가 된다.
#
# 이 결과로 서로 다른 thread의 호출이 중간에 끼어도 user1의 대화가 독립적으로 이어지는지 확인한다.

# %%
user_input3 = {
    "messages": [
        HumanMessage(
            content= "LangGraph 복습 계획 간략히 세우고, 내 이름도 알려줘"
        )
    ]
}

user1_state = graph.invoke(
    user_input3,
    config = user_config,
)

user1_state["messages"][-1].content
# Out:
# [{'type': 'text',
#   'text': '홍길동님입니다.\n\n### LangGraph 간략 복습 계획\n1. **핵심 개념 복습**: State, Node, Edge, Graph  \n2. **기본 그래프 구현**: 상태 정의 및 노드 연결  \n3. **조건부 흐름 학습**: 분기와 반복 처리  \n4. **메모리·체크포인트 복습**: 대화 상태 저장과 복원  \n5. **미니 프로젝트**: 질문 분류 → 도구 호출 → 답변 생성  \n6. **정리**: 주요 API와 코드 패턴 요약',
#   'annotations': [],
#   'id': 'msg_0c5cd33b01e067f0006a83f1ca2b2c87d0a88cdb6fd2a459c5',
#   'phase': 'final_answer'}]

# %% [markdown]
# ## 저장된 최신 Checkpoint를 StateSnapshot으로 확인하기
#
# **Checkpoint**는 Checkpointer에 저장된 기록이고, **StateSnapshot**은 그 기록을 Python에서 조회할 때 받는 객체이다. `graph.get_state(user1_config)`는 user1 thread의 **최신 Checkpoint 하나**를 StateSnapshot으로 반환한다.
#
# **두 필드 확인**
#
# - `values`: 해당 시점의 실제 State 값이다. 여기에는 누적된 `messages`가 들어 있다.
# - `next`: 다음에 실행할 Node 이름의 tuple이다. 그래프가 정상 종료되었으면 빈 tuple `()`이고, 값이 남아 있으면 중단되었거나 이어서 실행할 Node가 있다는 뜻이다.
#
# 입력은 `thread_id="user1"`인 config이고, 출력은 조회 전용 StateSnapshot이다.
#
# ### history와 resume의 범위
#
# - `graph.get_state()`: thread의 최신 snapshot 하나를 조회한다.
# - `graph.get_state_history()`: 같은 thread에 쌓인 여러 snapshot을 순서대로 조회할 때 사용하는 별도 API이다. 이 실습에서는 호출하지 않는다.
# - 같은 `thread_id`의 새 `graph.invoke()`: 최신 State를 복구한 뒤 새 Turn을 실행하는 **대화 이어가기**이다.
# - `Command(resume=...)`: interrupt로 멈춘 실행에 사람의 값을 전달해 재개하는 **중단 지점 resume**이다. 다음 Human-in-the-loop 노트북에서 다룬다.
#
# Tool 호출 여부에 따라 message 수는 달라질 수 있으므로 고정 숫자보다 user1의 세 Turn이 순서대로 포함되는지를 확인한다.

# %%
user1_snapshot = graph.get_state(user_config)

print("message count: ", len(user1_snapshot.values["messages"]))

# END로 끝난 상태이기 때문에 다음 Node 없음 == ()
print("next nodes: ", user1_snapshot.next)

display(user1_snapshot.values["messages"])
# Out:
# message count:  8
# next nodes:  ()
# [HumanMessage(content='반가워. 내 이름은 홍길동이야.', additional_kwargs={}, response_metadata={}, id='51327908-c7eb-4287-bb10-f4a1d28814cb'),
#  AIMessage(content=[{'type': 'text', 'text': '반가워요, 홍길동님! 무엇을 도와드릴까요?', 'annotations': [], 'id': 'msg_0c5cd33b01e067f0006a83ee85465087d0b827ccf751b2eab8', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0c5cd33b01e067f0006a83ee847b4887d097f3344ebba52f44', 'created_at': 1787031172.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0c5cd33b01e067f0006a83ee847b4887d097f3344ebba52f44', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1182, 'output_tokens': 22, 'total_tokens': 1204, 'input_token_details': {'cache_creation': 0, 'cache_read': 1179}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='내 이름이 뭐라고?', additional_kwargs={}, response_metadata={}, id='82d10328-aaaf-4efa-aef9-2f75df9c697f'),
#  AIMessage(content=[{'type': 'text', 'text': '홍길동님이에요.', 'annotations': [], 'id': 'msg_0c5cd33b01e067f0006a83efcee8f487d08f06f6b47fcab95e', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0c5cd33b01e067f0006a83efce0c9887d0b57dc62ff3602ca2', 'created_at': 1787031502.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0c5cd33b01e067f0006a83efce0c9887d0b57dc62ff3602ca2', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1216, 'output_tokens': 11, 'total_tokens': 1227, 'input_token_details': {'cache_creation': 34, 'cache_read': 1179}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='LangGraph 복습 계획 간략히 세우고, 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='2ea8cc2d-3223-474e-9cdc-255b9284a05a'),
#  AIMessage(content=[{'id': 'rs_0c5cd33b01e067f0006a83f1bedbdc87d0b9adaaa53f4547fd', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg
 'annotations': [], 'id': 'msg_0c5cd33b01e067f0006a83f1bf1bc887d0b41aa060aa497ff6', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0c5cd33b01e067f0006a83f1be5d1c87d0a78b51e67f015a7b', 'created_at': 1787031998.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0c5cd33b01e067f0006a83f1be5d1c87d0a78b51e67f015a7b', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1250, 'output_tokens': 168, 'total_tokens': 1418, 'input_token_details': {'cache_creation': 34, 'cache_read': 1213}, 'output_token_details': {'reasoning': 23}}),
#  HumanMessage(content='LangGraph 복습 계획 간략히 세우고, 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='6af16151-ca10-4cff-ad9e-df666731cb5e'),
#  AIMessage(content=[{'type': 'text', 'text': '홍길동님입니다.\n\n### LangGraph 간략 복습 계획\n1. **핵심 개념 복습**: State, Node, Edge, Graph  \n2. **기본 그래프 구현**: 상태 정의 및 노드 연결  \n3. **조건부 흐름 학습**: 분기와 반복 처리  \n4. **메모리·체크포인트 복습**: 대화 상태 저장과 복원  \n5. **미니 프로젝트**: 질문 분류 → 도구 호출 → 답변 생성  \n6. **정리**: 주요 API와 코드 패턴 요약', 'annotations': [], 'id': 'msg_0c5cd33b01e067f0006a83f1ca2b2c87d0a88cdb6fd2a459c5', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0c5cd33b01e067f0006a83f1c99a8c87d0a2ba0986ab300812', 'created_at': 1787032009.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0c5cd33b01e067f0006a83f1c99a8c87d0a2ba0986ab300812', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1441, 'output_tokens': 131, 'total_tokens': 1572, 'input_token_details': {'cache_creation': 191, 'cache_read': 1247}, 'output_token_details': {'reasoning': 0}})]

# %%
# 도구 호출 후 내역을 checkpoint에 기록
user_input4 = {
    "messages": [
        HumanMessage(
            content="거제 강수 피해에 대해서 알려줘"
        )
    ]
}

user1_state = graph.invoke(
    user_input4,
    config = user_config,
)

user1_state["messages"][-1].text
# Out:
# '최근 보도된 **거제 집중호우 피해**는 다음과 같습니다.\n\n- **기록적 강수량**: 2026년 8월 17일 거제에 하루 **577.4㎜**, 1시간 동안 **124.5㎜**의 비가 내렸습니다. 1972년 관측 이래 거제의 일강수량·시간강수량 기록을 경신한 수준입니다.\n- **주요 피해**: 옥포동 등에서 산사태와 토사 유출이 발생했고, 아파트 저층과 주택·도로가 침수됐습니다. 장평동 등에서는 차량 침수와 도로 유실도 발생했습니다.\n- **인명 피해**: 산사태로 **사망 1명, 부상 2명**이 발생한 것으로 보도됐습니다.\n- **생활·교통 피해**: 도로 약 20곳이 한때 통제되고 시내버스 운행에 차질이 생겼으며, 약 **1,500세대의 전력 공급**이 끊겼습니다. 일부 학교와 조선소 주변 시설도 피해를 입었습니다.\n- **원인**: 남쪽에서 유입된 고온다습한 공기가 남해안 지형과 충돌하면서 강한 비구름이 장시간 머문 것이 주요 원인으로 분석됐습니다.\n\n피해 규모와 복구 현황은 집계가 계속 바뀔 수 있으므로, 실제 대피·통제 정보는 **거제시 재난안전대책본부와 기상청의 최신 발표**를 확인해야 합니다.  \n※ 다른 연도나 특정 호우 사건을 말씀하신 것이라면 날짜를 알려주시면 그 사건 기준으로 정리해드릴게요.'

# %%
user1_snapshot = graph.get_state(user_config)

display(user1_snapshot.values["messages"])
# Out:
# [HumanMessage(content='반가워. 내 이름은 홍길동이야.', additional_kwargs={}, response_metadata={}, id='51327908-c7eb-4287-bb10-f4a1d28814cb'),
#  AIMessage(content=[{'type': 'text', 'text': '반가워요, 홍길동님! 무엇을 도와드릴까요?', 'annotations': [], 'id': 'msg_0c5cd33b01e067f0006a
82itRCUYitQhUschJUJfcEM3CtCq38n7fG8MIRA0RqsFvXfUxrpwx_L06WLwZs1wINM8L2qkvqgGOWNv88Jpa6VEFzxcEpjU5VB4uA28rIb88Y1PrUExhTGB_IE6BPVLAimw0xnEXdPV55kxSkgENRsYF_R-5Ep66pnlh2Qn2OYVZrmnUVXbTdHK_KmtsdzqxwZrsUoiU880h0NZaVbwkUQLzLMeq02djPQYjB3KxSBQ7U_'}, {'type': 'text', 'text': '홍길동님입니다.\n\n### LangGraph 간략 복습 계획\n1. **기초 개념**: State, Node, Edge, Graph 구조 이해  \n2. **간단한 그래프 구현**: 노드 연결 및 상태 전달 실습  \n3. **조건 분기**: ` conditional_edges`로 흐름 제어  \n4. **메모리와 체크포인트**: 대화 상태 저장 및 복원  \n5. **실전 미니 프로젝트**: 질문 분류 → 도구 호출 → 답변 생성 흐름 만들기  \n6. **복습 정리**: 자주 쓰는 API와 구현 패턴 요약하기', 'annotations': [], 'id': 'msg_0c5cd33b01e067f0006a83f1bf1bc887d0b41aa060aa497ff6', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0c5cd33b01e067f0006a83f1be5d1c87d0a78b51e67f015a7b', 'created_at': 1787031998.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0c5cd33b01e067f0006a83f1be5d1c87d0a78b51e67f015a7b', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1250, 'output_tokens': 168, 'total_tokens': 1418, 'input_token_details': {'cache_creation': 34, 'cache_read': 1213}, 'output_token_details': {'reasoning': 23}}),
#  HumanMessage(content='LangGraph 복습 계획 간략히 세우고, 내 이름도 알려줘', additional_kwargs={}, response_metadata={}, id='6af16151-ca10-4cff-ad9e-df666731cb5e'),
#  AIMessage(content=[{'type': 'text', 'text': '홍길동님입니다.\n\n### LangGraph 간략 복습 계획\n1. **핵심 개념 복습**: State, Node, Edge, Graph  \n2. **기본 그래프 구현**: 상태 정의 및 노드 연결  \n3. **조건부 흐름 학습**: 분기와 반복 처리  \n4. **메모리·체크포인트 복습**: 대화 상태 저장과 복원  \n5. **미니 프로젝트**: 질문 분류 → 도구 호출 → 답변 생성  \n6. **정리**: 주요 API와 코드 패턴 요약', 'annotations': [], 'id': 'msg_0c5cd33b01e067f0006a83f1ca2b2c87d0a88cdb6fd2a459c5', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0c5cd33b01e067f0006a83f1c99a8c87d0a2ba0986ab300812', 'created_at': 1787032009.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0c5cd33b01e067f0006a83f1c99a8c87d0a2ba0986ab300812', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1441, 'output_tokens': 131, 'total_tokens': 1572, 'input_token_details': {'cache_creation': 191, 'cache_read': 1247}, 'output_token_details': {'reasoning': 0}}),
#  HumanMessage(content='거제 강수 피해에 대해서 알려줘', additional_kwargs={}, response_metadata={}, id='8cb10a95-6f9a-4c51-b911-6e67d1f443ea'),
#  AIMessage(content=[{'id': 'rs_0c5cd33b01e067f0006a83f780010c87d0af5fa01ba4a7ecd9', 'summary': [], 'type': 'reasoning', 'content': [], 'encrypted_content': 'gAAAAABqg_eD7CFlCzJpZ-lmdtv4B6qnfumg9FAC9AOSKQVnUYcz30yVGQSwbvzNy6gKMW3uGydNexEAtd_LVix2fvC6F-7lLxAZ4-pxRqBlsuhM2vPZ9SiGWjU1PFTY_x2OrmKC7aXppfYbd2NWZYVpOFBV_3GFf5WkfGuySHV9uF5qnNAokVOEvC1XXloX-8hzV3NlRDwZNXqvp1YS51moueFgxX1mq47Y329oM4WEKbR7YJEpJHOhzC3K5umpCpldLC5krkujWFC6dGNKfpFnbW3Ov9ZBDeF35_Oh0YPNNAFfBAnmJlD
], 'exclude_domains': [], 'search_depth': 'advanced', 'include_images': False, 'time_range': 'year', 'topic': 'news', 'start_date': None, 'end_date': None}, 'id': 'call_sr9n80azzvkclZ6iXeigepXf', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 1587, 'output_tokens': 141, 'total_tokens': 1728, 'input_token_details': {'cache_creation': 146, 'cache_read': 1438}, 'output_token_details': {'reasoning': 36}}),
#  ToolMessage(content='{"query": "거제 강수 피해 최근 집중호우 피해 상황 복구 2025 2026 대한민국 거제시 강우 피해 뉴스 공식 발표", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.newsis.com/view/NISX20260818_0003752139", "title": "재난급 가뭄→역대급 \'괴물 비\'…극단의 롤러코스터, 왜? :: 공감언론 뉴시스 ::", "content": "2026.08.18 (화)\\n\\n서울 29.9℃\\n\\n페이스북\\n트위터\\n인스타그램\\n유튜브\\n네이버\\nRSS\\n모바일앱스토어\\n검색하기 버튼\\n엔샷\\n속보뉴스 더보기\\n기자채널 바로가기\\n검색하기\\nnewsis\\n페이스북\\n트위터\\n유튜브\\n검색리스트 보기\\n검색하기\\n\\n사회\\n\\n# 재난급 가뭄→역대급 \'괴물 비\'…극단의 롤러코스터, 왜?\\n\\n등록 2026.08.18 10:09:32수정 2026.08.18 10:11:38\\n\\n이메일 보내기\\n프린터\\nPDF\\n\\n## 거제 사흘간 927㎜·통영 751㎜ \'물폭탄\'\\n\\n## 기상청 \\"동쪽 고기압 강화가 핵심 원인\\"\\n\\n## 거제 특유 지형도 영향…국지성 호우↑\\n\\n![[거제=뉴시스] 차용현 기자 = 기록적인 폭우가 쏟아진 지난 17일 오후 경남 거제시 옥포동 인근 도로에 흙탕물이 거세게 흘러넘치자 경찰이 차량 통행을 막고 교통을 통제하고 있다. 2026.08.17. con@newsis.com](\\n\\n[거제=뉴시스] 차용현 기자 = 기록적인 폭우가 쏟아진 지난 17일 오후 경남 거제시 옥포동 인근 도로에 흙탕물이 거세게 흘러넘치자 경찰이 차량 통행을 막고 교통을 통제하고 있다. 2026.08.17. (/cdn-cgi/l/email-protection)\\n\\n[거제=뉴시스] 차용현 기자 = 기록적인 폭우가 쏟아진 지난 17일 오후 경남 거제시 옥포동 인근 도로에 흙탕물이 거세게 흘러넘치자 경찰이 차량 통행을 막고 교통을 통제하고 있다. 2026.08.17. (/cdn-cgi/l/email-protection)\\n\\n### 동쪽 고기압 강화로 인한 저기압 정체…남쪽 수증기도 유입 [...] \'물폭탄\' 피해 경남 거제·통영 학교 21곳 휴업\\n\\n김민석, 거제 수해현장 찾아 \\"민생 지키는 여당 되겠다\\"\\n\\n\'포레나힐스테이트 진주\' 분양…진주 이현동 주공아파트 재개발\\n\\n\\"검찰수사관 수사도 \'검사 수사개시\', 기소 못해\\"…첫 대법 판례 나왔다(종합)\\n\\n아산현충사IC서 경차 경계석 들이받고 전복…50대 숨져\\n\\n쌍용C&E 본사, 강원 동해시 이전 추진 \\"TF 조직해 준비\\"\\n\\n통영 \'물폭탄\' 국가유산도 덮쳤다…김상옥 생가 등 침수\\n\\n\'킬쇼\' 원작자 강지영, 이번엔 퇴마…귀신 아닌 탐욕에 빙의됐다\\n\\n\\"AI 시대 인간은…\\" 호반문화재단, 뇌과학자 정재승 교수 특강\\n\\n통영 \'물폭탄\' 국가유산도 덮쳤다…김상옥 생가 등 침수\\n\\n나홍진 \'호프\', 홍콩 여름 국제영화제 개막작…홍상수 초기작 특별전\\n\\n문화체육관광부\\n\\n더한옥헤리티지, 포브스 트래블 가이드 \'큐레이티드 멤버십\' 선정\\n\\n우리 고궁박물관에서 결혼해…내년엔 80쌍\\n\\n공유숙박 어떻게 창업·운영할까…‘K-Stay Expo 2026’ 10월 DDP\\n\\n이강인, 아틀레티코 공식 입단식 가져…\\"모든 대회서 우승 원해\\"\\n\\n홍명보 후임 찾은 축구협회, 이번 주 임시감독 면접 갖는다\\n\\n재정비 후 돌아오는 김서현·정우주, 한화 구세주 될 수 있을까\\n\\n\'존폐 위기\' LIV 골프, 미시간 대회 취소…시즌 조기 종료\\n\\n송성문 소속팀 MLB 샌디에이고, 매각 승인…매각 규모 5조5000억원 \'사상 최고\'\\n\\n\\"첫 만남도 구찌, 결혼식도 구찌\\"…호날두♥조지나의 10년 러브 스토리\\n\\n문화체육관광부\\n\\n\'KLPGA 3승\' 서교림, 세계랭킹 9계단 오른 40위 [...] ### 동쪽 고기압 강화로 인한 저기압 정체…남쪽 수증기도 유입\\n\\n### 거제도 지형도 \'거들었다\'…해안선·산맥이 강수 집중 도와\\n\\n![[거제=뉴시스] 차용현 기자 = 지난 17일 오전 밤사이 내린 폭우로 경남 거제시 거제대로 인근 한 아파트 뒤편에서 산사태가 발생해 쏟아져 내린 토사가 주차된 차량 등을 덮쳐 피해가 발생했다. 2026.08.17. con@newsis.com](\\n\\n[거제=뉴시스] 차용현 기자 = 지난 17일 오전 밤사이 내린 폭우로 경남 거제시 거제대로 인근 한 아파트 뒤편에서 산사태가 발생해 쏟아져 내린 토사가 주차된 차량 등을 덮쳐 피해가 발생했다. 2026.08.17. (/cdn-cgi/l/email-protection)\\n\\n[거제=뉴시스] 차용현 기자 = 지난 17일 오전 밤사이 내린 폭우로 경남 거제시 거제대로 인근 한 아파트 뒤편에서 산사태가 발생해 쏟아져 내린 토사가 주차된 차량 등을 덮쳐 피해가 발생했다. 2026.08.17. (/cdn-cgi/l/email-protection)\\n\\n### 국지성 집중호우, 늘어나고 있나…\\"여름철 종종 발생\\"\\n\\n### 가뭄 뒤 폭우, 산사태 더 유발했나\\n\\nCopyright © NEWSIS.COM, 무단 전재 및 재배포 금지\\n\\n관련기사\\n\\n다음 구독베너\\n네이버 구독베너\\n\\n많이 본 사진\\n\\nN샷\\n\\nN샷\\n\\n꽃보다 사나\\n\\n기대되는 \'대등왜\'\\n\\n훈훈 라이즈\\n\\n컴백하는 스키즈\\n\\n미모의 필릭스\\n\\n현진의 눈빛\\n\\n뉴시스Pic\\n\\n기록적인 폭우 내린 경남 거제·통영… 도로 파손되고 건물은 침수\\n\\n장동혁, 일정 취소하고 거제로… 
Tsh_gAk-8bouyNTy0FALC1w3TlRoG45p_g5hNcMX1oGJZqXOjM6gZi3WmWLM-Uku8XsXY7i57F6DlVPXYSF63EbTDqZyS08wPOv3ETylqvqvoHoLLcklTnxw38F_T7q9aafa-wfVffRrxRoYe2ATrAh-a8CwGp-oyKon32_dGmoHnqmbB1ijWTjnkoDSuwvMHPoEA9r7_GLVYkk_2Xl-RKu3W89NZGEHnyHIWIcrK6hR0GAdMc3owXzFMumZBMC1OCZBjdVxzD0MNKUb2uZHU7LaU1hjCZFSsZ6qAgNaC1CWn-GKPzexL6A89fh4CubrXVHyWoc1_5DsL-3gp-A2Y36zN4-ar4sMMqfH9k2UYcEzcetXhkxJXtMJ5p2TLFbDzLiH0ECvg6rqgyIKlAz1_ZRxWRNnXAh45P0g_Cg__7B3-hiHrCVEHIuZc9tp0rfdjazT9M9j6DQl9kp0wlmISKZH-xP8uRpZCFp4ZA12w-8uWkfsV0wr9vXswDlG3kHuxa1StzOuZlE-lP1gCFK_vARAYBAcyAILV4e_WpsdQY8f_HbabJhqjZOazhUHG1Ahuneqww_r4QXk-kUWyLPDGCFBTg8sJGV54KzTEr0JgFw6EFFD_6LGnWc14g='}, {'arguments': '{"query":"거제 강수 피해 집중호우 피해 강수량 침수 산사태","include_domains":["geoje.go.kr","yna.co.kr","khan.co.kr","kado.net"],"exclude_domains":[],"search_depth":"advanced","include_images":false,"time_range":"year","topic":"general","start_date":null,"end_date":null}', 'call_id': 'call_lvBoOpFeIioor29260ibZ11s', 'name': 'tavily_search', 'type': 'function_call', 'id': 'fc_0c5cd33b01e067f0006a83f78c769887d09e5cf8ec11b83633', 'status': 'completed'}, {'arguments': '{"query":"거제시 호우 피해 재난안전대책본부 침수 산사태 공식","include_domains":["geoje.go.kr"],"exclude_domains":[],"search_depth":"advanced","include_images":false,"time_range":"year","topic":"general","start_date":null,"end_date":null}', 'call_id': 'call_TiEQrDXbsWau8u5GvVtQaVeF', 'name': 'tavily_search', 'type': 'function_call', 'id': 'fc_0c5cd33b01e067f0006a83f78c76a887d0819e7c9555614dac', 'status': 'completed'}], additional_kwargs={}, response_metadata={'id': 'resp_0c5cd33b01e067f0006a83f789b1d887d0b760b469ab08e2a6', 'created_at': 1787033481.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0c5cd33b01e067f0006a83f789b1d887d0b760b469ab08e2a6', tool_calls=[{'name': 'tavily_search', 'args': {'query': '거제 강수 피해 집중호우 피해 강수량 침수 산사태', 'include_domains': ['geoje.go.kr', 'yna.co.kr', 'khan.co.kr', 'kado.net'], 'exclude_domains': [], 'search_depth': 'advanced', 'include_images': False, 'time_range': 'year', 'topic': 'general', 'start_date': None, 'end_date': None}, 'id': 'call_lvBoOpFeIioor29260ibZ11s', 'type': 'tool_call'}, {'name': 'tavily_search', 'args': {'query': '거제시 호우 피해 재난안전대책본부 침수 산사태 공식', 'include_domains': ['geoje.go.kr'], 'exclude_domains': [], 'search_depth': 'advanced', 'include_images': False, 'time_range': 'year', 'topic': 'general', 'start_date': None, 'end_date': None}, 'id': 'call_TiEQrDXbsWau8u5GvVtQaVeF', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 3740, 'output_tokens': 268, 'total_tokens': 4008, 'input_token_details': {'cache_creation': 2153, 'cache_read': 1584},  ...
#  ToolMessage(content='{"query": "거제 강수 피해 집중호우 피해 강수량 침수 산사태", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.yna.co.kr/view/AKR20260817009752052", "title": "거제·통영 역대급 호우…경남 남해안 곳곳 산사태·침수 피해(종합2보) | 연합뉴스", "content": "이미지 확대  집중호우가 할퀴고 간 거제 옥포동 상가\\n\\n집중호우가 할퀴고 간 거제 옥포동 상가\\n\\n(거제=연합뉴스) 정종호 기자 = 17일 오전 경남 거제시 옥포동 한 상가 일대에서 집중호우로 점포 유리창이 깨지고 도로 아스팔트가 뜯겨 나가는 등 피해가 발생했다. 2026.8.17 jjh23@yna.co.kr\\n\\n(거제=연합뉴스) 이정훈 김선경 기자 = 이번 광복절 연휴 3일간 경남 전역에 가뭄 해갈에 도움이 되는 비가 내렸으나 거제·통영을 비롯한 남해안에는 물폭탄 수준의 집중호우가 쏟아져 인명·재산피해가 잇따랐다.\\n\\n극한호우 여파로 발생한 산사태가 인근 아파트 저층을 덮치는가 하면 도로 곳곳이 유실되고 물에 잠겨 시내·시외버스 등 대중교통 운행에 차질이 빚어지기도 했다.\\n\\n이미지 확대  흙탕물에 잠긴 거제 옥포동 도로\\n\\n흙탕물에 잠긴 거제 옥포동 도로\\n\\n(거제=연합뉴스) 정종호 기자 = 17일 오전 경남 거제시 옥포동 도로가 집중호우로 불어난 흙탕물에 잠겨 있다. 2026.8.17 jjh23@yna.co.kr\\n\\n◇ 거제 124.5㎜·통영 97.4㎜…기상 관측 이래 1시간 강수량 신기록\\n\\n경남 남해안 일원에는 이날 새벽 기록적으로 많은 비가 내렸다.\\n\\n기상청에 따르면 거제에는 이날 오전 1시 32분부터 1시간 동안 124.5㎜의 극한호우가 쏟아졌다. 1972년 1월 24일 거제에서 기상관측을 시작한 이래 1시간 강수량 신기록이다.\\n\\n기상청은 시간당 100㎜ 호우 상황에서는 넘쳐흐르는 물에 도로의 차량이 뜨기 시작하고, 대부분의 시설물·건물의 하단이 물에 잠긴다고 설명한다. [...] 통영에는 오전 5시 11분부터 1시간 동안 97.4㎜의 비가 내렸다. 이 역시 통영에서 기상관측을 시작(1968년 1월 1일)한 이래 1시간 강수량 신기록에 해당한다.\\n\\n이미지 확대  물바다 된 거제 장평동 도로\\n\\n물바다 된 거제 장평동 도로\\n\\n(거제=연합뉴스) 17일 오전 경남 거제시 장평동 일대에 내린 집중호우로 도로가 침수돼 차들이 물에 잠겨 있다. 2026.8.17 [독자 제공. 재판매 및 DB 금지] ymp@yna.co.kr\\n\\n비가 내리기 시작한 지난 15일 광복절부터 이날 오전 9시까지 누적 강수량(거제 810.2㎜·통영 678.9㎜)을 평년(1991∼2020년 평균) 여름 강수량(거제 935.1㎜·통영 728.8㎜)과 비교해보면, 거제와 통영에는 여름 한철 내릴 비 90%가량이 최근 사흘 동안 집중됐을 정도로 역대급 호우가 쏟아졌다.\\n\\n사천(삼천포)과 고성에도 광복절 연휴 사흘간 353.5㎜, 고성 334.0㎜의 많은 비가 내렸다.\\n\\n낮 12시 기준으로 거제에는 아직도 호우경보가, 통영·사천·고성·남해·창원에는 호우주의보가 내려져 있다.\\n\\n이번 비로 거제를 비롯한 통영·사천·고성 등 경남 다수 지역이 올해 지속된 유례 없는 가뭄 걱정에서는 벗어나게 됐지만, 순식간에 덮쳐온 수마에 또 다른 근심을 떠안게 됐다.\\n\\n이미지 확대  토사에 발 빠진 시민 구조하는 소방대원들\\n\\n토사에 발 빠진 시민 구조하는 소방대원들 [...] 이미지 확대  집중호우가 할퀴고 간 거제 옥포동 상가\\n\\n  집중호우가 할퀴고 간 거제 옥포동 상가\\n\\n  (거제=연합뉴스) 정종호 기자 = 17일 오전 경남 거제시 옥포동 한 상가 일대에서 집중호우로 점포 유리창이 깨지고 도로 아스팔트가 뜯겨 나가는 등 피해가 발생했다. 2026.8.17 jjh23@yna.co.kr\\n\\n  2026-08-17 12:30\\n 이미지 확대  흙탕물에 잠긴 거제 옥포동 도로\\n\\n  흙탕물에 잠긴 거제 옥포동 도로\\n\\n  (거제=연합뉴스) 정종호 기자 = 17일 오전 경남 거제시 옥포동 도로가 집중호우로 불어난 흙탕물에 잠겨 있다. 2026.8.17 jjh23@yna.co.kr\\n\\n  2026-08-17 12:22\\n 이미지 확대  물바다 된 거제 장평동 도로\\n\\n  물바다 된 거제 장평동 도로\\n\\n  (거제=연합뉴스) 17일 오전 경남 거제시 장평동 일대에 내린 집중호우로 도로가 침수돼 차들이 물에 잠겨 있다. 2026.8.17 [독자 제공. 재판매 및 DB 금지] ymp@yna.co.kr\\n\\n  2026-08-17 12:31\\n 이미지 확대  토사에 발 빠진 시민 구조하는 소방대원들\\n\\n  토사에 발 빠진 시민 구조하는 소방대원들\\n\\n  (거제=연합뉴스) 17일 오전 경남 거제시 연초면에서 집중호우로 흘러내린 토사에 발이 빠져 움직이지 못하던 시민을 소방대원들이 구조하고 있다. 2026.8.17 [경남소방본부 제공. 재판매 및 DB 금지] ymp@yna.co.kr\\n\\n  2026-08-17 12:27\\n 이미지 확대  산사태 토사 덮친 거제 아파트\\n\\n  산사태 토사 덮친 거제 아파트", "score": 0.86928266, "raw_content": null, "id": "a51291-00"}, {"url": "https://www.yna.co.kr/amp/view/AKR20260817044000054", "title": "남해안 \'극한호우\'에 1명 사망·4명 부상…인명피해 거제 집중 | 연합뉴스", "content": "국가기간뉴스 통신사 연합뉴스\\n\\n# 남해안 \'극한호우\'에 1명 사망·4명 부상…인명피해 거제 집중\\n\\n송고2026-08-17 15:16\\n\\n송고 2026년08월17일 15시16분\\n\\n구글에서 선호하는 출처로 추가\\n\\n박철홍기자\\n\\n## 거제 일강수량 577.4㎜ \'전국 역대 3위\'…태풍 루사 이래 최다\\n\\n## 피해 신고 838건·주민 159명 대피…가뭄은 남부 일부 해소\\n\\n(전국종합=연합뉴스) 광복절 연휴 마지막 날인 17일 경남 거제에 570㎜가 넘는 기록적인 폭우가 쏟아지는 등 한반도 남부에 집중호우로 인한 피해가 발생했다.\\n\\n거제에는 2002년 태풍 루사 이후 전국 97개 종관기상관측지점에서 가장 많은 일강수량이 하루 만에 쏟아져 산사태 등으로 1명이 숨지고 4명이 다쳤다.\\n\\n주택·도로 침수 등 피해 신고는 838건으로 늘었고 부산과 경남 주민 150여명이 대피했다.\\n\\n이미지 확대\\n\\n집중호우로 물에 잠긴 도로\\n\\n(거제=연합뉴스) 김동민 기자 = 17일 오후 경남 거제시 옥포동 도로가 집중호우로 물에 잠겼다. 2026.8.17 image@yna.co.kr\\n\\n◇ 거제에 하루 동안 577.4㎜ 폭우…역대 3번째 수치\\n\\n기상청에 따르면 거제에는 이날 0시부터 오후 1시까지 577.4㎜의 비가 내려 1972년 관측 시작 이래 지역 일강수량 최고 기록을 경신했다.\\n\\n전국 97개 종관기상관측지점의 역대 일강수량 가운데서도 2002년 8월 31일 태풍 루사 당시 강릉 870.5㎜와 대관령 712.5㎜에 이어 세 번째로 많다.\\n\\n통영도 409.7㎜로 1968년 관측 시작 이후 일강수량 최고치를 기록했다. [...] 통영도 409.7㎜로 1968년 관측 시작 이후 일강수량 최고치를 기록했다.\\n\\n거제에는 1시간 동안 124.5㎜, 통영에는 97.4㎜가 쏟아져 시간당 강수량 기록도 각각 경신했다.\\n\\n기상청은 거제와 통영의 시간당 강수 강도를 각각 200년과 100년에 한 번 나타날 수준으로 분석했다.\\n\\n남해안 다른 지역과 제주산지를 중심으로도 많은 비가 내렸으며 지난 15일부터 이날 오후 1시까지 누적 강수량은 거제 851.1㎜, 통영 704.8㎜, 부산 가덕도 441 ...
#  ToolMessage(content='{"query": "거제시 호우 피해 재난안전대책본부 침수 산사태 공식", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "http://tour.geoje.go.kr/index.geoje?menuCd=DOM_000008902001002001&m=D&idx=68523&searchType=&keyword=&DEP_NM=&NOT_ANCMT_SJ=&NOT_ANCMT_CN=", "title": "소통참여 > 시정뉴스 > 고시/공고 > 고시공고 | 거제시청", "content": "Title: 소통참여 > 시정뉴스 > 고시/공고 > 고시공고 | 거제시청\\n이 누리집은 대한민국 공식 전자정부 누리집입니다. * 中文 \\"중문홈페이지가 새 창으로 열립니다.\\"). * 日文 \\"일문홈페이지가 새 창으로 열립니다.\\"). # BIG HEART GEOJE. + 부동산 투기 공익신고 센터 운영. + 개인정보 목적 외 이용 및 제3자 제공내역. + 부동산 투기 공익신고 센터 운영. ### 고시공고. 2026년 산림재난대응단(산사태 현장예방단)채용 합격자 공고. **고시공고관리번호**거제시 공고 제2026-1039호. **담당자 연락처** 055-639-4353. 2026년 산림재난대응단(산사태 현장예방단) 채용 합격자 공고문.hwp 채용 합격자 공고문.hwp\',\'2026년 산림재난대응단(산사태 현장예방단) 채용 합격자 공고문_ofr_ofr_Y5i5O5MzuYyGbQJu_20260423175447661_1.hwp\',\'/ntishome/file/upload/ofr/ofr/20260423\') \\"2026년 산림재난대응단(산사태 현장예방단) 채용 합격자 공고문.hwp 다운로드\\")\xa0 바로보기. 2026년 산림재난대응단(산사태 현장예방단)채용 합격자를 다음과 같이 공고하고자 합니다. 나. 합 격 자 : 공고문 참고. 나. 장
SKPDm2T9sro0JV2MNVKNotV0mXd4CkMrhg0R3M8-xawk1X_QRoSFdtL0rlWPUNOQ0gRuTlatGSVQmwYAoxq-uTD97O_QlqbXXzYRpr6wFAXUTN_wYJNgqKW3nkPvlJSfyG1VsYCRBALcd1HR3yzTKQGVBf_niEPkksLatunONX9WqM3SDIas73gXnIWncH2_kNL2Z0M_lTIUSB0H54N0N6wu-kMRnn8JsEMndo-0M7I36anndXTGKfHGVqLKdMgiG4AUpucIzK0v-fyDrRI73gR_cMFG64HrmzSIyutwd7tOsE1CMVLXQEyMX9QlgGbaavGMQu9TcqzaHF3eIIYWFTdaeXUIHwkFr8dfr8x2e-a5AXRZ2ZutMPSSPHSL06Z2PELX1g1sHYSEHRcYa0vp3FI4DNzWwGkFX9Rm8lAKAHeUUQxtPBoknAhf0dEaHK9uzR2r_GdjK02aXbY4dBnd8OYjsP-gOhchCEtOYePNarP62NoYMo2FmHOpas5vP8IAwRZGsuX6hnjK5vESaoN7v2FG7wu3aVJE79nmZJJzRUWXPnHWt8TaNfaeH4pvG8_1juSwLB2rIgaGQhiWG8_4kgqIDtw7j5zcr5m1d8B-yD6-cZhxErey9YZa4-trYtiadCCtVfSNPXf1pQoY8uciF_EBmi3eOX1pOROuGpTqfFneqKrg=='}, {'type': 'text', 'text': '최근 보도된 **거제 집중호우 피해**는 다음과 같습니다.\n\n- **기록적 강수량**: 2026년 8월 17일 거제에 하루 **577.4㎜**, 1시간 동안 **124.5㎜**의 비가 내렸습니다. 1972년 관측 이래 거제의 일강수량·시간강수량 기록을 경신한 수준입니다.\n- **주요 피해**: 옥포동 등에서 산사태와 토사 유출이 발생했고, 아파트 저층과 주택·도로가 침수됐습니다. 장평동 등에서는 차량 침수와 도로 유실도 발생했습니다.\n- **인명 피해**: 산사태로 **사망 1명, 부상 2명**이 발생한 것으로 보도됐습니다.\n- **생활·교통 피해**: 도로 약 20곳이 한때 통제되고 시내버스 운행에 차질이 생겼으며, 약 **1,500세대의 전력 공급**이 끊겼습니다. 일부 학교와 조선소 주변 시설도 피해를 입었습니다.\n- **원인**: 남쪽에서 유입된 고온다습한 공기가 남해안 지형과 충돌하면서 강한 비구름이 장시간 머문 것이 주요 원인으로 분석됐습니다.\n\n피해 규모와 복구 현황은 집계가 계속 바뀔 수 있으므로, 실제 대피·통제 정보는 **거제시 재난안전대책본부와 기상청의 최신 발표**를 확인해야 합니다.  \n※ 다른 연도나 특정 호우 사건을 말씀하신 것이라면 날짜를 알려주시면 그 사건 기준으로 정리해드릴게요.', 'annotations': [], 'id': 'msg_0c5cd33b01e067f0006a83f79518a087d09b23c9f6ca38d19f', 'phase': 'final_answer'}], additional_kwargs={}, response_metadata={'id': 'resp_0c5cd33b01e067f0006a83f79322f087d0a74b33fb0f867b3a', 'created_at': 1787033491.0, 'metadata': {}, 'model': 'gpt-5.6-luna', 'object': 'response', 'service_tier': 'default', 'status': 'completed', 'model_provider': 'openai', 'model_name': 'gpt-5.6-luna'}, id='resp_0c5cd33b01e067f0006a83f79322f087d0a74b33fb0f867b3a', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8264, 'output_tokens': 486, 'total_tokens': 8750, 'input_token_details': {'cache_creation': 4524, 'cache_read': 3737}, 'output_token_details': {'reasoning': 95}})]
